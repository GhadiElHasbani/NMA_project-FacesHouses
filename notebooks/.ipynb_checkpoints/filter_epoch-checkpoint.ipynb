# %%
import mne
import mne_bids
import numpy as np

# %%
bids_root = "/Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/BIDS"
output_dir = "/Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/output"
subjects_dir = "/Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/fs_subjects"

# %%
for subject in ["ap"]:
    subject = "ca"

    path = mne_bids.BIDSPath(root=bids_root, subject=subject, session="clean", task="train", datatype="ieeg")
    raw = mne_bids.read_raw_bids(path, extra_params=dict(preload=True))
    
    montage = raw.get_montage()

    # add fiducials to montage
    montage.add_estimated_fiducials(f"{subjects_dir}/{subject}")

    trans = mne.channels.compute_native_head_t(montage)

    # now with fiducials assigned, the montage will be properly converted
    # to "head" which is what MNE requires internally (this is the coordinate
    # system with the origin between LPA and RPA whereas MNI has the origin
    # at the posterior commissure)
    raw.set_montage(montage)
    
    raw.filter(0.15, None, n_jobs=-1)
    raw.notch_filter(range(60, 500, 60), method="spectrum_fit", filter_length="5s", n_jobs=-1)
# Out:
# Extracting parameters from /Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/BIDS/sub-ca/ses-clean/ieeg/sub-ca_ses-clean_task-train_ieeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 271359  =      0.000 ...   271.359 secs...
# Reading events from /Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/BIDS/sub-ca/ses-clean/ieeg/sub-ca_ses-clean_task-train_events.tsv.
# Reading channel info from /Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/BIDS/sub-ca/ses-clean/ieeg/sub-ca_ses-clean_task-train_channels.tsv.
# Reading electrode coords from /Users/daniel/Documents/Coding_Projects/GitHub/NMA-FacesHouses/data/BIDS/sub-ca/ses-clean/ieeg/sub-ca_ses-clean_space-ACPC_electrodes.tsv.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.15 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.15
# - Lower transition bandwidth: 0.15 Hz (-6 dB cutoff frequency: 0.07 Hz)
# - Filter length: 22001 samples (22.001 sec)
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    1.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:   22.6s finished
# Removed notch frequencies (Hz):
#      60.00 : 5350 windows
#     120.00 : 5350 windows
#     180.00 : 5350 windows
#     239.00 :   50 windows
#     240.00 : 5350 windows
#     241.00 :   50 windows
#     299.00 : 5350 windows
#     300.00 : 5350 windows
#     301.00 : 5350 windows
#     359.00 : 5350 windows
#     360.00 : 5350 windows
#     361.00 : 5350 windows
#     419.00 : 5350 windows
#     420.00 : 5350 windows
#     421.00 : 5350 windows
#     479.00 : 5350 windows
#     480.00 : 5350 windows
#     481.00 : 5350 windows

# %%
raw.
# Out:
# Effective window size : 2.048 (s)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNELineFigure size 1000x350 with 2 Axes>
